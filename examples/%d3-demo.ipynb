# %%
# %load_ext py_d3

# %%
# %d3
# Out:
# 4.13.0
# 4.12.2
# 4.12.1
# 4.12.0
# 4.11.0
# 4.10.2
# 4.10.1
# 4.10.0
# 4.9.1
# 4.9.0
# 4.8.0
# 4.7.4
# 4.7.3
# 4.7.2
# 4.7.1
# 4.7.0
# 4.6.0
# 4.5.1
# 4.5.0
# 4.4.4
# 4.4.3
# 4.4.2
# 4.4.1
# 4.4.0
# 4.3.0
# 4.2.8
# 4.2.7
# 4.2.6
# 4.2.5
# 4.2.4
# 4.2.3
# 4.2.2
# 4.2.1
# 4.2.0
# 4.1.1
# 4.1.0
# 4.0.0-rc.2
# 4.0.0-rc.1
# 4.0.0-alpha.50
# 4.0.0-alpha.49
# 4.0.0-alpha.48
# 4.0.0-alpha.47
# 4.0.0-alpha.46
# 4.0.0-alpha.45
# 4.0.0-alpha.44
# 4.0.0-alpha.43
# 4.0.0-alpha.42
# 4.0.0-alpha.41
# 4.0.0-alpha.40
# 4.0.0-alpha.39
# 4.0.0-alpha.38
# 4.0.0-alpha.37
# 4.0.0-alpha.36
# 4.0.0-alpha.35
# 4.0.0-alpha.34
# 4.0.0-alpha.33
# 4.0.0-alpha.32
# 4.0.0-alpha.31
# 4.0.0-alpha.30
# 4.0.0-alpha.29
# 4.0.0-alpha.28
# 4.0.0-alpha.27
# 4.0.0-alpha.26
# 4.0.0-alpha.25
# 4.0.0-alpha.24
# 4.0.0-alpha.23
# 4.0.0-alpha.22
# 4.0.0-alpha.21
# 4.0.0-alpha.20
# 4.0.0-alpha.19
# 4.0.0-alpha.18
# 4.0.0-alpha.17
# 4.0.0-alpha.16
# 4.0.0-alpha.15
# 4.0.0-alpha.14
# 4.0.0-alpha.13
# 4.0.0-alpha.12
# ...

# %%
# %d3 releases
# Out:
# 4.13.0
# 4.12.2
# 4.12.1
# 4.12.0
# 4.11.0
# 4.10.2
# 4.10.1
# 4.10.0
# 4.9.1
# 4.9.0
# 4.8.0
# 4.7.4
# 4.7.3
# 4.7.2
# 4.7.1
# 4.7.0
# 4.6.0
# 4.5.1
# 4.5.0
# 4.4.4
# 4.4.3
# 4.4.2
# 4.4.1
# 4.4.0
# 4.3.0
# 4.2.8
# 4.2.7
# 4.2.6
# 4.2.5
# 4.2.4
# 4.2.3
# 4.2.2
# 4.2.1
# 4.2.0
# 4.1.1
# 4.1.0
# 4.0.0-rc.2
# 4.0.0-rc.1
# 4.0.0-alpha.50
# 4.0.0-alpha.49
# 4.0.0-alpha.48
# 4.0.0-alpha.47
# 4.0.0-alpha.46
# 4.0.0-alpha.45
# 4.0.0-alpha.44
# 4.0.0-alpha.43
# 4.0.0-alpha.42
# 4.0.0-alpha.41
# 4.0.0-alpha.40
# 4.0.0-alpha.39
# 4.0.0-alpha.38
# 4.0.0-alpha.37
# 4.0.0-alpha.36
# 4.0.0-alpha.35
# 4.0.0-alpha.34
# 4.0.0-alpha.33
# 4.0.0-alpha.32
# 4.0.0-alpha.31
# 4.0.0-alpha.30
# 4.0.0-alpha.29
# 4.0.0-alpha.28
# 4.0.0-alpha.27
# 4.0.0-alpha.26
# 4.0.0-alpha.25
# 4.0.0-alpha.24
# 4.0.0-alpha.23
# 4.0.0-alpha.22
# 4.0.0-alpha.21
# 4.0.0-alpha.20
# 4.0.0-alpha.19
# 4.0.0-alpha.18
# 4.0.0-alpha.17
# 4.0.0-alpha.16
# 4.0.0-alpha.15
# 4.0.0-alpha.14
# 4.0.0-alpha.13
# 4.0.0-alpha.12
# ...

# %%
# %%d3 releases
# <g></g>
# Out:
# 4.13.0
# 4.12.2
# 4.12.1
# 4.12.0
# 4.11.0
# 4.10.2
# 4.10.1
# 4.10.0
# 4.9.1
# 4.9.0
# 4.8.0
# 4.7.4
# 4.7.3
# 4.7.2
# 4.7.1
# 4.7.0
# 4.6.0
# 4.5.1
# 4.5.0
# 4.4.4
# 4.4.3
# 4.4.2
# 4.4.1
# 4.4.0
# 4.3.0
# 4.2.8
# 4.2.7
# 4.2.6
# 4.2.5
# 4.2.4
# 4.2.3
# 4.2.2
# 4.2.1
# 4.2.0
# 4.1.1
# 4.1.0
# 4.0.0-rc.2
# 4.0.0-rc.1
# 4.0.0-alpha.50
# 4.0.0-alpha.49
# 4.0.0-alpha.48
# 4.0.0-alpha.47
# 4.0.0-alpha.46
# 4.0.0-alpha.45
# 4.0.0-alpha.44
# 4.0.0-alpha.43
# 4.0.0-alpha.42
# 4.0.0-alpha.41
# 4.0.0-alpha.40
# 4.0.0-alpha.39
# 4.0.0-alpha.38
# 4.0.0-alpha.37
# 4.0.0-alpha.36
# 4.0.0-alpha.35
# 4.0.0-alpha.34
# 4.0.0-alpha.33
# 4.0.0-alpha.32
# 4.0.0-alpha.31
# 4.0.0-alpha.30
# 4.0.0-alpha.29
# 4.0.0-alpha.28
# 4.0.0-alpha.27
# 4.0.0-alpha.26
# 4.0.0-alpha.25
# 4.0.0-alpha.24
# 4.0.0-alpha.23
# 4.0.0-alpha.22
# 4.0.0-alpha.21
# 4.0.0-alpha.20
# 4.0.0-alpha.19
# 4.0.0-alpha.18
# 4.0.0-alpha.17
# 4.0.0-alpha.16
# 4.0.0-alpha.15
# 4.0.0-alpha.14
# 4.0.0-alpha.13
# 4.0.0-alpha.12
# ...
