# %% [markdown]
# # <center>Generating online code examples</center>
# You can load online code examples through a simple GUI (requires [`ipywidgets` module](https://ipywidgets.readthedocs.io/en/latest/user_install.html): `pip install ipywidgets`).

# %%
# %run ../py_d3/py_d3.py

# %% [markdown]
# Only load the code generator, copy paste your example name and click in `Generate` button. The code example will appears in the next cell and the necessary data files will be downloaded and stored in the current directory.

# %%
# %d3 generator
# Out:
# Accordion(children=(Box(children=(Text(value='', layout=Layout(height='80px', width='50%'), placeholder='Insert a example name and it will be rendered in a new cell.'), Button(button_style='success', description='Generate', icon='code', layout=Layout(width='20%'), style=ButtonStyle())), layout=Layout(height='40px')), HTML(value='<h3>D3 v4 online examples</h3><table style="width:100%"><tr><th>Name</th><th>Thumbnail</th><th>User</th></tr><tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3007180">Exoplanets</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3007180/raw/thumbnail.png" width="65px" height="20px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3048450">Histogram</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3048450/raw/thumbnail.png" width="65px" height="20px" alt=" "></d><td><a href="http://github.com/mbostock">mbosto
# ...

# %% [markdown]
# The `generator` command works with search filter parameters of the [`generate` command](%d3-examples.ipynb).

# %%
# %d3 generator user="mbostock"
# Out:
# Accordion(children=(Box(children=(Text(value='', layout=Layout(height='80px', width='50%'), placeholder='Insert a example name and it will be rendered in a new cell.'), Button(button_style='success', description='Generate', icon='code', layout=Layout(width='20%'), style=ButtonStyle())), layout=Layout(height='40px')), HTML(value='<h3>D3 v4 online examples</h3><table style="width:100%"><tr><th>Name</th><th>Thumbnail</th><th>User</th></tr><tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3007180">Exoplanets</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3007180/raw/thumbnail.png" width="65px" height="20px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3048450">Histogram</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3048450/raw/thumbnail.png" width="65px" height="20px" alt=" "></d><td><a href="http://github.com/mbostock">mbosto
# ...

# %% [markdown]
# > See also:
# - [Basic usage](basic_usage.ipynb)
# - [`%d3 examples` usage](%d3-examples.ipynb)
