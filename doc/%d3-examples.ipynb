# %% [markdown]
# # <center>Running online examples</center>
# > `py_d3` uses [blockbuilder.org](http://blockbuilder.org/) API to search examples by D3 version.

# %%
# %run ../py_d3/py_d3.py

# %% [markdown]
# You can get all the online examples for the version of D3 currently in use.

# %%
# %d3 examples

# %% [markdown]
# As default, searched examples are from version in use. To see that:

# %%
# %d3 version

# %% [markdown]
# You can filter by several fields in the search. For example, see the examples in other version (only is possible indicate the major versions `2`, `3` and `4`):

# %%
# %d3 examples version=3

# %% [markdown]
# And, if we could filter by user?

# %%
# %d3 examples user="mbostock"
# Out:
# HTML(value='<h3>D3 v4 online examples</h3><table style="width:100%"><tr><th>Name</th><th>Thumbnail</th><th>User</th></tr><tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3007180">Exoplanets</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3007180/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3048450">Histogram</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3048450/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3035090">Area with Missing Data</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3035090/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/1014829">External SVG</a></td><td><img src="http://gist.githubusercontent.com/mbostock/1014829/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/1643051">Line Transition (Broken)</a></td><td><img src="http://gist.githubusercontent.com/mbostock/1643051/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/1642989">Spline Transition</a></td><td><img src="http://gist.githubusercontent.com/mbostock/1642989/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3943967">Stacked-to-Grouped Bars</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3943967/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3734321">Lambert Conformal Conic</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3734321/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3712408">Cylindrical Equal-Area</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3712408/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3757119">Equirectangular (Plate Carrée)</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3757119/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3757101">Lambert Azimuthal Equal-Area</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3757101/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3763867">Guyou</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3763867/raw/thumbnail.png" width="70px" height="25px" alt=" "></d><td><a href="http://github.com/mbostock">mbostock</a></td><td><a button</tr>\n<tr><td><a target="_blank" href="http://blockbuilder.org/mbostock/3886394">Normalized Stacked Bar Chart</a></td><td><img src="http://gist.githubusercontent.com/mbostock/3886394/raw/thumbnail.png" width="70px" height="25px" alt=" "></d ...

# %% [markdown]
# > If you want to submit your own examples see [Enjalot's blockbuilder github repository](https://github.com/enjalot/blockbuilder).

# %% [markdown]
# You can filter by D3 modules passing the argument as a list. The examples on the result will have these modules in use.

# %%
# %d3 examples modules=["d3-legend", "d3-geo"]

# %% [markdown]
# If you want to know what are all the valid modules passed to this command use:

# %%
# %d3 modules

# %% [markdown]
# > See also:
# - [Basic usage](basic_usage.ipynb)
# - [`%d3 generator` usage](%d3-generator.ipynb)
